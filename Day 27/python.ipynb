# %%
a=10
A=20
c=a+A
print(c)
# Out:
# 30

# %%
def add(a,b):
  return c
add(10,20)
# Out:
# 30

# %%
a=(1,2,3,[1,2])
print(a)
b=[1,2,(1,2)]
print(b)
# Out:
# (1, 2, 3, [1, 2])
# [1, 2, (1, 2)]

# %%
a="helloworld"
a=[0]="q"
# Out:
#   File "/tmp/ipykernel_1389/22666576.py", line 2
#     a=[0]="q"
#        ^
# SyntaxError: cannot assign to literal

# %%
a="hello"
print(a)
l=list(a)
print(l)
l[0]="a"
print(l)
s="".join(l)
print(s)
# Out:
# hello
# ['h', 'e', 'l', 'l', 'o']
# ['a', 'e', 'l', 'l', 'o']
# aello

# %%
a=20
c=list[a]
print(c)
# Out:
# list[20]

# %%
a=10
b=8
c=10**8
print(c)
# Out:
# 100000000

# %%
print(4+(8**2)-3**2%1)
# Out:
# 68

# %%
print(4%(1+9)**2-60//(7+2))
# Out:
# -2

# %%
a=10
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
# Out:
# 15
# 5
# 50
# 2.0
# 0
# 2

# %%
print(8*9+(3**3)//9)
# Out:
# 75

# %%
a="A"
b="Hello"
print(a+b)
# Out:
# AHello

# %%
a="ping_pong_hello"
for i in a:
  if i=='-':
    pop(i)
print(1)
# Out:
# 1

# %%
a=[2,5,(1,2)]
print(a)
b=[2,33,222,14,25]
print(b[-5])
c=['1','2','3','4']
c[:]=[]
print(c)
# Out:
# {2, (1, 2), 5}
# 2
# []
