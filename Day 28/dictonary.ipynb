# %%
d1={"India":"INR","USA":"Dollars","Japan":"yen","Germany":"Euro"}
print(d1)
# Out:
# {'India': 'INR', 'USA': 'Dollars', 'Japan': 'yen', 'Germany': 'Euro'}

# %%
d1["India"]="Rupeee"
print(d1)
# Out:
# {'India': 'Rupeee', 'USA': 'Dollars', 'Japan': 'yen', 'Germany': 'Euro'}

# %%
Employee_data={
    101:["A",25,"Sales"],
    102:["B",27,"Marketing"],
    103:["C",25,"HR"],
    104:["D",29,"Product Lead"],
    105:["E",31,"IT"]
}
print(Employee_data)
# Out:
# {101: ['A', 25, 'Sales'], 102: ['B', 27, 'Marketing'], 103: ['C', 25, 'HR'], 104: ['D', 29, 'Product Lead'], 105: ['E', 31, 'IT']}

# %%
d1.values()
# Out:
# dict_values(['Rupeee', 'Dollars', 'yen', 'Euro'])

# %%
d1.keys()
# Out:
# dict_keys(['India', 'USA', 'Japan', 'Germany'])

# %%
del d1["USA"]
print(d1)
# Out:
# {'India': 'Rupeee', 'Japan': 'yen', 'Germany': 'Euro'}

# %%
len(d1)
# Out:
# 3

# %%
max(d1)
# Out:
# 'Japan'

# %%
min(d1)
# Out:
# 'Germany'

# %%
sorted(d1.values())
# Out:
# ['Euro', 'Rupeee', 'yen']

# %%
sorted(d1.keys())
# Out:
# ['Germany', 'India', 'Japan']

# %%
d1.update(India="Rupee")
print(d1)
# Out:
# {'India': 'Rupee', 'Japan': 'yen', 'Germany': 'Euro'}

# %%
d1.get("India")
# Out:
# 'Rupee'

# %%
dict1={"India":"INR","USA":"Dollars","Japan":"yen","Germany":"Euro"}
for i in dict1:
  print(i,dict1[i])
# Out:
# India INR
# USA Dollars
# Japan yen
# Germany Euro

# %%
for i in dict1:
  print(i)
# Out:
# India
# USA
# Japan
# Germany

# %%
for i in dict1.values():
  print(i)
# Out:
# INR
# Dollars
# yen
# Euro

# %%
for i in dict1.items():
  print(i)
# Out:
# ('India', 'INR')
# ('USA', 'Dollars')
# ('Japan', 'yen')
# ('Germany', 'Euro')

# %%
for i in dict1.keys():
  print(i)
# Out:
# India
# USA
# Japan
# Germany

# %%
for i,j in dict1.items():
  print(i,j)
# Out:
# India INR
# USA Dollars
# Japan yen
# Germany Euro
